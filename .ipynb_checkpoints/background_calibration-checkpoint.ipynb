# %%
# %load_ext autoreload
# %autoreload 2
import h5py 
import scipy 
import numpy as np 
import matplotlib.pyplot as plt 
from comborun.base  import ComboRun, exclusion_pc
from bkgrnd import BackgroundRun
from run_ranges import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bg_file = '/home/tejvarmay/scattering_data/data/newdata/data00579_bg_100.h5'
bkgrnd_run = BackgroundRun(bg_file)

bkgrnd_run.hist_i(range=(90, 110), bins=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       1 bg_file = '/home/tejvarmay/scattering_data/data/newdata/data00579_bg_100.h5'
#       2 bkgrnd_run = BackgroundRun(bg_file)
# ----> 4 bkgrnd_run.hist_i(range=(90, 110), bins=10)
#
# TypeError: hist_i() got an unexpected keyword argument 'range'

# %%
bkgrnd_run.bg.shape
# Out:
# (700, 700)

# %%
plt.figure()
plt.imshow(bkgrnd_run.bg)
plt.colorbar()
plt.figure()
plt.imshow(bkgrnd_run.bg_std)
plt.colorbar()
plt.figure()
plt.imshow(bkgrnd_run.good_pixels)
plt.colorbar()

np.unique(bkgrnd_run.good_pixels)
# Out:
# array([False,  True])

# %%
# %load_ext autoreload
# %autoreload 2
import h5py 
import scipy 
import numpy as np 
import matplotlib.pyplot as plt 
from comborun  import ComboRun
from bkgrnd import BackgroundRun

# %%
bg_file = '/home/tejvarmay/scattering_data/data/newdata/data00579_bg_100.h5'
bkgrnd_run = BackgroundRun(bg_file)

bkgrnd_run.hist_i(range=(90, 110), bins=19)

# %%
bkgrnd_run.bg.shape
# Out:
# (700, 700)

# %%
plt.figure()
plt.imshow(bkgrnd_run.bg)
plt.colorbar()
plt.figure()
plt.imshow(bkgrnd_run.bg_std)
plt.colorbar()
plt.figure()
plt.imshow(bkgrnd_run.good_pixels)
plt.colorbar()

np.unique(bkgrnd_run.good_pixels)
# Out:
# array([False,  True])
